# %%
import pandas as pd

df = pd.read_csv("/content/sales_orders.csv")
df.head()
# Out:
#    Unnamed: 0  order_id  order_date   ship_date customer_id customer_name  \
# 0           0  ORD-1000  01/01/2023  03/01/2023     CUST-39         Diana
# 1           1  ORD-1001  02/01/2023  04/01/2023     CUST-29         Fiona
# 2           2  ORD-1002  03/01/2023  05/01/2023     CUST-15         Helen
# 3           3  ORD-1003  04/01/2023  06/01/2023     CUST-43         Diana
# 4           4  ORD-1004  05/01/2023  07/01/2023      CUST-8         Fiona
#
#        segment region         category sub_category product_name   sales  \
# 0     Consumer   East       Technology       Tables    Product B  455.75
# 1  Home Office  South       Technology       Tables    Product A  367.66
# 2    Corporate   West        Furniture       Chairs    Product C  379.60
# 3     Consumer  North  Office Supplies  Accessories    Product D   90.04
# 4  Home Office  South  Office Supplies       Phones    Product A   69.34
#
#    quantity  discount  profit
# 0         2      0.00  157.92
# ...
